# %%
import pandas as pd

# Đọc file CSV
file_path = "WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(file_path)

# Xem 5 dòng đầu tiên
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Kiểm tra thông tin dữ liệu
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
from pymongo import MongoClient

# Kết nối đến MongoDB
client = MongoClient("mongodb+srv://nguyenminhy7714:minhy112@cluster0.xxkrzas.mongodb.net/")

# Tạo database
db = client["telco_churn"]

# %%
customer_info = df[["customerID", "gender", "SeniorCitizen", "Partner", "Dependents"]]
db.customer_info.insert_many(customer_info.to_dict(orient="records"))
# Out:
# InsertManyResult([ObjectId('67d1018d52105dd7bdb19826'), ObjectId('67d1018d52105dd7bdb19827'), ObjectId('67d1018d52105dd7bdb19828'), ObjectId('67d1018d52105dd7bdb19829'), ObjectId('67d1018d52105dd7bdb1982a'), ObjectId('67d1018d52105dd7bdb1982b'), ObjectId('67d1018d52105dd7bdb1982c'), ObjectId('67d1018d52105dd7bdb1982d'), ObjectId('67d1018d52105dd7bdb1982e'), ObjectId('67d1018d52105dd7bdb1982f'), ObjectId('67d1018d52105dd7bdb19830'), ObjectId('67d1018d52105dd7bdb19831'), ObjectId('67d1018d52105dd7bdb19832'), ObjectId('67d1018d52105dd7bdb19833'), ObjectId('67d1018d52105dd7bdb19834'), ObjectId('67d1018d52105dd7bdb19835'), ObjectId('67d1018d52105dd7bdb19836'), ObjectId('67d1018d52105dd7bdb19837'), ObjectId('67d1018d52105dd7bdb19838'), ObjectId('67d1018d52105dd7bdb19839'), ObjectId('67d1018d52105dd7bdb1983a'), ObjectId('67d1018d52105dd7bdb1983b'), ObjectId('67d1018d52105dd7bdb1983c'), ObjectId('67d1018d52105dd7bdb1983d'), ObjectId('67d1018d52105dd7bdb1983e'), ObjectId('67d1018d52105dd7bdb1
# ...

# %%
phone_service = df[["customerID", "PhoneService", "MultipleLines"]]
db.phone_service.insert_many(phone_service.to_dict(orient="records"))
# Out:
# InsertManyResult([ObjectId('67d1019b52105dd7bdb1b3a9'), ObjectId('67d1019b52105dd7bdb1b3aa'), ObjectId('67d1019b52105dd7bdb1b3ab'), ObjectId('67d1019b52105dd7bdb1b3ac'), ObjectId('67d1019b52105dd7bdb1b3ad'), ObjectId('67d1019b52105dd7bdb1b3ae'), ObjectId('67d1019b52105dd7bdb1b3af'), ObjectId('67d1019b52105dd7bdb1b3b0'), ObjectId('67d1019b52105dd7bdb1b3b1'), ObjectId('67d1019b52105dd7bdb1b3b2'), ObjectId('67d1019b52105dd7bdb1b3b3'), ObjectId('67d1019b52105dd7bdb1b3b4'), ObjectId('67d1019b52105dd7bdb1b3b5'), ObjectId('67d1019b52105dd7bdb1b3b6'), ObjectId('67d1019b52105dd7bdb1b3b7'), ObjectId('67d1019b52105dd7bdb1b3b8'), ObjectId('67d1019b52105dd7bdb1b3b9'), ObjectId('67d1019b52105dd7bdb1b3ba'), ObjectId('67d1019b52105dd7bdb1b3bb'), ObjectId('67d1019b52105dd7bdb1b3bc'), ObjectId('67d1019b52105dd7bdb1b3bd'), ObjectId('67d1019b52105dd7bdb1b3be'), ObjectId('67d1019b52105dd7bdb1b3bf'), ObjectId('67d1019b52105dd7bdb1b3c0'), ObjectId('67d1019b52105dd7bdb1b3c1'), ObjectId('67d1019b52105dd7bdb1
# ...

# %%
internet_service = df[[
    "customerID", "InternetService", "OnlineSecurity", "OnlineBackup", 
    "DeviceProtection", "TechSupport", "StreamingTV", "StreamingMovies"
]]
db.internet_service.insert_many(internet_service.to_dict(orient="records"))
# Out:
# InsertManyResult([ObjectId('67d101a652105dd7bdb1cf2c'), ObjectId('67d101a652105dd7bdb1cf2d'), ObjectId('67d101a652105dd7bdb1cf2e'), ObjectId('67d101a652105dd7bdb1cf2f'), ObjectId('67d101a652105dd7bdb1cf30'), ObjectId('67d101a652105dd7bdb1cf31'), ObjectId('67d101a652105dd7bdb1cf32'), ObjectId('67d101a652105dd7bdb1cf33'), ObjectId('67d101a652105dd7bdb1cf34'), ObjectId('67d101a652105dd7bdb1cf35'), ObjectId('67d101a652105dd7bdb1cf36'), ObjectId('67d101a652105dd7bdb1cf37'), ObjectId('67d101a652105dd7bdb1cf38'), ObjectId('67d101a652105dd7bdb1cf39'), ObjectId('67d101a652105dd7bdb1cf3a'), ObjectId('67d101a652105dd7bdb1cf3b'), ObjectId('67d101a652105dd7bdb1cf3c'), ObjectId('67d101a652105dd7bdb1cf3d'), ObjectId('67d101a652105dd7bdb1cf3e'), ObjectId('67d101a652105dd7bdb1cf3f'), ObjectId('67d101a652105dd7bdb1cf40'), ObjectId('67d101a652105dd7bdb1cf41'), ObjectId('67d101a652105dd7bdb1cf42'), ObjectId('67d101a652105dd7bdb1cf43'), ObjectId('67d101a652105dd7bdb1cf44'), ObjectId('67d101a652105dd7bdb1
# ...

# %%
contract_info = df[["customerID", "Contract", "PaperlessBilling", "PaymentMethod"]]
db.contract_info.insert_many(contract_info.to_dict(orient="records"))
# Out:
# InsertManyResult([ObjectId('67d101b352105dd7bdb1eaaf'), ObjectId('67d101b352105dd7bdb1eab0'), ObjectId('67d101b352105dd7bdb1eab1'), ObjectId('67d101b352105dd7bdb1eab2'), ObjectId('67d101b352105dd7bdb1eab3'), ObjectId('67d101b352105dd7bdb1eab4'), ObjectId('67d101b352105dd7bdb1eab5'), ObjectId('67d101b352105dd7bdb1eab6'), ObjectId('67d101b352105dd7bdb1eab7'), ObjectId('67d101b352105dd7bdb1eab8'), ObjectId('67d101b352105dd7bdb1eab9'), ObjectId('67d101b352105dd7bdb1eaba'), ObjectId('67d101b352105dd7bdb1eabb'), ObjectId('67d101b352105dd7bdb1eabc'), ObjectId('67d101b352105dd7bdb1eabd'), ObjectId('67d101b352105dd7bdb1eabe'), ObjectId('67d101b352105dd7bdb1eabf'), ObjectId('67d101b352105dd7bdb1eac0'), ObjectId('67d101b352105dd7bdb1eac1'), ObjectId('67d101b352105dd7bdb1eac2'), ObjectId('67d101b352105dd7bdb1eac3'), ObjectId('67d101b352105dd7bdb1eac4'), ObjectId('67d101b352105dd7bdb1eac5'), ObjectId('67d101b352105dd7bdb1eac6'), ObjectId('67d101b352105dd7bdb1eac7'), ObjectId('67d101b352105dd7bdb1
# ...

# %%
billing_info = df[["customerID", "MonthlyCharges", "TotalCharges"]]
db.billing_info.insert_many(billing_info.to_dict(orient="records"))
# Out:
# InsertManyResult([ObjectId('67d101c152105dd7bdb20632'), ObjectId('67d101c152105dd7bdb20633'), ObjectId('67d101c152105dd7bdb20634'), ObjectId('67d101c152105dd7bdb20635'), ObjectId('67d101c152105dd7bdb20636'), ObjectId('67d101c152105dd7bdb20637'), ObjectId('67d101c152105dd7bdb20638'), ObjectId('67d101c152105dd7bdb20639'), ObjectId('67d101c152105dd7bdb2063a'), ObjectId('67d101c152105dd7bdb2063b'), ObjectId('67d101c152105dd7bdb2063c'), ObjectId('67d101c152105dd7bdb2063d'), ObjectId('67d101c152105dd7bdb2063e'), ObjectId('67d101c152105dd7bdb2063f'), ObjectId('67d101c152105dd7bdb20640'), ObjectId('67d101c152105dd7bdb20641'), ObjectId('67d101c152105dd7bdb20642'), ObjectId('67d101c152105dd7bdb20643'), ObjectId('67d101c152105dd7bdb20644'), ObjectId('67d101c152105dd7bdb20645'), ObjectId('67d101c152105dd7bdb20646'), ObjectId('67d101c152105dd7bdb20647'), ObjectId('67d101c152105dd7bdb20648'), ObjectId('67d101c152105dd7bdb20649'), ObjectId('67d101c152105dd7bdb2064a'), ObjectId('67d101c152105dd7bdb2
# ...

# %%
churn_info = df[["customerID", "Churn"]]
db.churn_info.insert_many(churn_info.to_dict(orient="records"))
# Out:
# InsertManyResult([ObjectId('67d101ce52105dd7bdb221b5'), ObjectId('67d101ce52105dd7bdb221b6'), ObjectId('67d101ce52105dd7bdb221b7'), ObjectId('67d101ce52105dd7bdb221b8'), ObjectId('67d101ce52105dd7bdb221b9'), ObjectId('67d101ce52105dd7bdb221ba'), ObjectId('67d101ce52105dd7bdb221bb'), ObjectId('67d101ce52105dd7bdb221bc'), ObjectId('67d101ce52105dd7bdb221bd'), ObjectId('67d101ce52105dd7bdb221be'), ObjectId('67d101ce52105dd7bdb221bf'), ObjectId('67d101ce52105dd7bdb221c0'), ObjectId('67d101ce52105dd7bdb221c1'), ObjectId('67d101ce52105dd7bdb221c2'), ObjectId('67d101ce52105dd7bdb221c3'), ObjectId('67d101ce52105dd7bdb221c4'), ObjectId('67d101ce52105dd7bdb221c5'), ObjectId('67d101ce52105dd7bdb221c6'), ObjectId('67d101ce52105dd7bdb221c7'), ObjectId('67d101ce52105dd7bdb221c8'), ObjectId('67d101ce52105dd7bdb221c9'), ObjectId('67d101ce52105dd7bdb221ca'), ObjectId('67d101ce52105dd7bdb221cb'), ObjectId('67d101ce52105dd7bdb221cc'), ObjectId('67d101ce52105dd7bdb221cd'), ObjectId('67d101ce52105dd7bdb2
# ...

# %%
print("Customer Info:", db.customer_info.count_documents({}))
print("Phone Service:", db.phone_service.count_documents({}))
print("Internet Service:", db.internet_service.count_documents({}))
print("Contract Info:", db.contract_info.count_documents({}))
print("Billing Info:", db.billing_info.count_documents({}))
print("Churn Info:", db.churn_info.count_documents({}))
# Out:
# Customer Info: 7043
# Phone Service: 7043
# Internet Service: 7043
# Contract Info: 7043
# Billing Info: 7043
# Churn Info: 7043
